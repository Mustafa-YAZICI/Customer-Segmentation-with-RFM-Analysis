# %% [markdown]
# # RFM Analizi ile Müşteri Segmentasyonu

# %%
# # RFM Analizi ile Müşteri Segmentasyonu

# #--------------------------------------------------------------------------------------------------------------------------#

# # İş Problemi
# # Online ayakkabı mağazası olan FLO müşterilerini
# # segmentlere ayırıp bu segmentlere göre pazarlama
# # stratejileri belirlemek istiyor. Buna yönelik olarak
# # müşterilerin davranışları tanımlanacak ve bu
# # davranışlardaki öbeklenmelere göre gruplar oluşturulacak.
# #--------------------------------------------------------------------------------------------------------------------------#
# #Veri Seti Hikayesi

# Veri seti Flo’dan son alışverişlerini 2020 - 2021 yıllarında OmniChannel (hem online hem offline alışveriş yapan) 
# olarak yapan müşterilerin geçmiş alışveriş davranışlarından elde edilen bilgilerden oluşmaktadır. 
# 12 Değişken 19.945 Gözlem 2.7MB

# master_id Eşsiz müşteri numarası
# order_channel Alışveriş yapılan platforma ait hangi kanalın kullanıldığı (Android, ios, Desktop, Mobile)
# last_order_channel En son alışverişin yapıldığı kanal
# first_order_date Müşterinin yaptığı ilk alışveriş tarihi
# last_order_date Müşterinin yaptığı son alışveriş tarihi
# last_order_date_online Müşterinin online platformda yaptığı son alışveriş tarihi
# last_order_date_offline Müşterinin offline platformda yaptığı son alışveriş tarihi
# order_num_total_ever_online Müşterinin online platformda yaptığı toplam alışveriş sayısı
# order_num_total_ever_offline Müşterinin offline'da yaptığı toplam alışveriş sayısı
# customer_value_total_ever_offline Müşterinin offline alışverişlerinde ödediği toplam ücret
# customer_value_total_ever_online Müşterinin online alışverişlerinde ödediği toplam ücret
# interested_in_categories_12 Müşterinin son 12 ayda alışveriş yaptığı kategorilerin listesi
# #--------------------------------------------------------------------------------------------------------------------------#


# Proje Görevleri

# # Görev 1: Veriyi Anlama ve Hazırlama

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: flo_data_20K.csv verisini okuyunuz.Dataframe’in kopyasını oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 2: Veri setinde
# a. İlk 10 gözlem,
# b. Değişken isimleri,
# c. Betimsel istatistik,
# d. Boş değer,
# e. Değişken tipleri, incelemesi yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Omnichannel müşterilerin hem online'dan hemde offline platformlardan alışveriş yaptığını ifade etmektedir. Her bir müşterinin toplam
# alışveriş sayısı ve harcaması için yeni değişkenler oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 4: Değişken tiplerini inceleyiniz. Tarih ifade eden değişkenlerin tipini date'e çeviriniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 5: Alışveriş kanallarındaki müşteri sayısının, toplam alınan ürün sayısının ve toplam harcamaların dağılımına bakınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 6: En fazla kazancı getiren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 7: En fazla siparişi veren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 8: Veri ön hazırlık sürecini fonksiyonlaştırınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# #--------------------------------------------------------------------------------------------------------------------------#

    

# #Görev 2: RFM Metriklerinin Hesaplanması

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: Recency, Frequency ve Monetary tanımlarını yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Müşteri özelinde Recency, Frequency ve Monetary metriklerini hesaplayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Hesapladığınız metrikleri rfm isimli bir değişkene atayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 4: Oluşturduğunuz metriklerin isimlerini recency, frequency ve monetary olarak değiştiriniz.
# recency değerini hesaplamak için analiz tarihini maksimum tarihten 2 gün sonrası seçebilirsiniz
# #--------------------------------------------------------------------------------------------------------------------------#


# #Görev 3: RF Skorunun Hesaplanması

# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: Recency, Frequency ve Monetary metriklerini qcut yardımı ile 1-5 arasında skorlara çeviriniz. 
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Bu skorları recency_score, frequency_score ve monetary_score olarak kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: recency_score ve frequency_score’u tek bir değişken olarak ifade ediniz ve RF_SCORE olarak kaydediniz. 

# #--------------------------------------------------------------------------------------------------------------------------#
# #--------------------------------------------------------------------------------------------------------------------------#
    
# #Görev 4: RF Skorunun Segment Olarak Tanımlanması
    
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: Oluşturulan RF skorları için segment tanımlamaları yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Aşağıdaki seg_map yardımı ile skorları segmentlere çeviriniz.
# RFM isimlendirmesi
# seg_map = {
#     r'[1-2][1-2]': 'hibernating',  # birinci elemanında 1 yada 2,ikinci elemanında 1 yada 2 görürsen onları hibernating yap
#     r'[1-2][3-4]': 'at_Risk',
#     r'[1-2]5': 'cant_loose',
#     r'3[1-2]': 'about_to_sleep',
#     r'33': 'need_attention',
#     r'[3-4][4-5]': 'loyal_customers',
#     r'41': 'promising',
#     r'51': 'new_customers',
#     r'[4-5][2-3]': 'potential_loyalists',
#     r'5[4-5]': 'champions'
# }

# #--------------------------------------------------------------------------------------------------------------------------#

# #Görev 5: Aksiyon Zamanı 

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: Segmentlerin recency, frequnecy ve monetary ortalamalarını inceleyiniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: RFM analizi yardımıyla aşağıda verilen 2 case için ilgili profildeki müşterileri bulun ve müşteri id'lerini csv olarak kaydediniz.

#     a. FLO bünyesine yeni bir kadın ayakkabı markası dahil ediyor. Dahil ettiği markanın ürün fiyatları genel müşteri
# tercihlerinin üstünde. Bu nedenle markanın tanıtımı ve ürün satışları için ilgilenecek profildeki müşterilerle özel olarak
# iletişime geçmek isteniliyor. Sadık müşterilerinden(champions, loyal_customers) ve kadın kategorisinden alışveriş
# yapan kişiler özel olarak iletişim kurulacak müşteriler. Bu müşterilerin id numaralarını csv dosyasına kaydediniz.
#     b. Erkek ve Çocuk ürünlerinde %40'a yakın indirim planlanmaktadır. Bu indirimle ilgili kategorilerle ilgilenen geçmişte
# iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler, uykuda olanlar ve yeni
# gelen müşteriler özel olarak hedef alınmak isteniyor. Uygun profildeki müşterilerin id'lerini csv dosyasına kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#

# %% [markdown]
# # Görev 1: Veriyi Anlama ve Hazırlama

# %%
# # Görev 1: Veriyi Anlama ve Hazırlama

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: flo_data_20K.csv verisini okuyunuz.Dataframe’in kopyasını oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 2: Veri setinde
# a. İlk 10 gözlem,
# b. Değişken isimleri,
# c. Betimsel istatistik,
# d. Boş değer,
# e. Değişken tipleri, incelemesi yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Omnichannel müşterilerin hem online'dan hemde offline platformlardan alışveriş yaptığını ifade etmektedir. Her bir müşterinin toplam
# alışveriş sayısı ve harcaması için yeni değişkenler oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 4: Değişken tiplerini inceleyiniz. Tarih ifade eden değişkenlerin tipini date'e çeviriniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 5: Alışveriş kanallarındaki müşteri sayısının, toplam alınan ürün sayısının ve toplam harcamaların dağılımına bakınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 6: En fazla kazancı getiren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 7: En fazla siparişi veren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 8: Veri ön hazırlık sürecini fonksiyonlaştırınız.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
import warnings
warnings.filterwarnings('ignore')

from IPython.display import Image
import datetime as dt
from datetime import timedelta, date
import pandas as pd
from sklearn.preprocessing import MinMaxScaler
#from sklearn.cluster import KMeans

import plotly.graph_objs as go
from plotly.offline import iplot

pd.set_option('display.max_columns', None)
# pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.4f' % x)    #!!!!!!!!!!!!!!!!!!!!!!!!!!

# %%
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: flo_data_20K.csv verisini okuyunuz.Dataframe’in kopyasını oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#    
#df_ = pd.read_excel("datasets/online_retail_II.xlsx", sheet_name="Year 2009-2010") excel için örnek
path="C:\\Users\\Msı\\PycharmProjects\\DSMLBC9\WEEK_2\\Proje_1_FLO_RFM_Analizi\\flo_data_20K.csv"
df_ = pd.read_csv(path)

# %%
df = df_.copy()
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 3           2021-01-06      2021-01-17             2021-01-17
# 4           2019-08-03      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19940       2019-09-21      2020-07-05             2020-06-05
# 19941       2020-03-01      2020-12-22             2020-12-22
# 19942       2019-09-11      2021-05-24             2021-05-24
# 19943       2019-03-27      2021-02-13             2021-02-13
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 3                  2021-01-06                       1.0000
# 4                  2019-08-03                       1.0000
# ...                       ...                          ...
# 19940              2020-07-05                       1.0000
# 19941              2020-03-01                       1.0000
# 19942              2019-09-11                       2.0000
# 19943              2021-01-08                       1.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 3                            1.0000                            39.9900
# 4                            1.0000                            49.9900
# ...                             ...                                ...
# 19940                        2.0000                           289.9800
# 19941                        1.0000                           150.4800
# 19942                        1.0000                           139.9800
# 19943                        5.0000                           711.7900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 3                               81.9800               [AKTIFCOCUK, COCUK]
# 4                              159.9900                       [AKTIFSPOR]
# ...                                 ...                               ...
# 19940                          111.9800                [ERKEK, AKTIFSPOR]
# 19941                          239.9900                       [AKTIFSPOR]
# 19942                          492.9600                       [AKTIFSPOR]
# 19943                          297.9800                [ERKEK, AKTIFSPOR]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
# [19945 rows x 12 columns]

# %%
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 2: Veri setinde
# a. İlk 10 gözlem,
# b. Değişken isimleri,
# c. Betimsel istatistik,
# d. Boş değer,
# e. Değişken tipleri, incelemesi yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
df.head()
# Out:
#                               master_id order_channel last_order_channel  \
# 0  cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4  d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
#
#   first_order_date last_order_date last_order_date_online  \
# 0       2020-10-30      2021-02-26             2021-02-21
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
# 4       2019-08-03      2021-03-07             2021-03-07
#
#   last_order_date_offline  order_num_total_ever_online  \
# 0              2021-02-26                       4.0000
# 1              2020-01-10                      19.0000
# 2              2019-12-01                       3.0000
# 3              2021-01-06                       1.0000
# 4              2019-08-03                       1.0000
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                        1.0000                           139.9900
# 1                        2.0000                           159.9700
# 2                        2.0000                           189.9700
# 3                        1.0000                            39.9900
# 4                        1.0000                            49.9900
#
#    customer_value_total_ever_online       interested_in_categories_12
# 0                          799.3800                           [KADIN]
# 1                         1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                          395.3500                    [ERKEK, KADIN]
# 3                           81.9800               [AKTIFCOCUK, COCUK]
# 4                          159.9900                       [AKTIFSPOR]

# %%
df.columns
# Out:
# Index(['master_id', 'order_channel', 'last_order_channel', 'first_order_date',
#        'last_order_date', 'last_order_date_online', 'last_order_date_offline',
#        'order_num_total_ever_online', 'order_num_total_ever_offline',
#        'customer_value_total_ever_offline', 'customer_value_total_ever_online',
#        'interested_in_categories_12'],
#       dtype='object')

# %%
df.describe().T
# Out:
#                                        count     mean      std     min  \
# order_num_total_ever_online       19945.0000   3.1109   4.2256  1.0000
# order_num_total_ever_offline      19945.0000   1.9139   2.0629  1.0000
# customer_value_total_ever_offline 19945.0000 253.9226 301.5329 10.0000
# customer_value_total_ever_online  19945.0000 497.3217 832.6019 12.9900
#
#                                        25%      50%      75%        max
# order_num_total_ever_online         1.0000   2.0000   4.0000   200.0000
# order_num_total_ever_offline        1.0000   1.0000   2.0000   109.0000
# customer_value_total_ever_offline  99.9900 179.9800 319.9700 18119.1400
# customer_value_total_ever_online  149.9800 286.4600 578.4400 45220.1300

# %%
df.isnull().sum()
# Out:
# master_id                            0
# order_channel                        0
# last_order_channel                   0
# first_order_date                     0
# last_order_date                      0
# last_order_date_online               0
# last_order_date_offline              0
# order_num_total_ever_online          0
# order_num_total_ever_offline         0
# customer_value_total_ever_offline    0
# customer_value_total_ever_online     0
# interested_in_categories_12          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 12 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 1.8+ MB

# %%
df["interested_in_categories_12"].nunique()
# Out:
# 32

# %%
df.groupby("order_channel").agg({"customer_value_total_ever_online":"sum",
                                "customer_value_total_ever_offline":"sum"}).sort_values(by="customer_value_total_ever_online",ascending=False)
# Out:
#                customer_value_total_ever_online  \
# order_channel
# Android App                        5448900.5500
# Mobile                             1828428.9700
# Ios App                            1772300.5500
# Desktop                             869451.0400
#
#                customer_value_total_ever_offline
# order_channel
# Android App                         2370162.2100
# Mobile                              1199754.1900
# Ios App                              753699.3800
# Desktop                              740870.4200

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Omnichannel müşterilerin hem online'dan hemde offline platformlardan alışveriş yaptığını ifade etmektedir. Her bir müşterinin toplam
# alışveriş sayısı ve harcaması için yeni değişkenler oluşturunuz.
# #--------------------------------------------------------------------------------------------------------------------------#
df["customer_value_total"]=df["customer_value_total_ever_online"]+df["customer_value_total_ever_offline"]
df["order_num_total"]=df["order_num_total_ever_online"]+df["order_num_total_ever_offline"]
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 3           2021-01-06      2021-01-17             2021-01-17
# 4           2019-08-03      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19940       2019-09-21      2020-07-05             2020-06-05
# 19941       2020-03-01      2020-12-22             2020-12-22
# 19942       2019-09-11      2021-05-24             2021-05-24
# 19943       2019-03-27      2021-02-13             2021-02-13
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 3                  2021-01-06                       1.0000
# 4                  2019-08-03                       1.0000
# ...                       ...                          ...
# 19940              2020-07-05                       1.0000
# 19941              2020-03-01                       1.0000
# 19942              2019-09-11                       2.0000
# 19943              2021-01-08                       1.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 3                            1.0000                            39.9900
# 4                            1.0000                            49.9900
# ...                             ...                                ...
# 19940                        2.0000                           289.9800
# 19941                        1.0000                           150.4800
# 19942                        1.0000                           139.9800
# 19943                        5.0000                           711.7900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12  \
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 3                               81.9800               [AKTIFCOCUK, COCUK]
# 4                              159.9900                       [AKTIFSPOR]
# ...                                 ...                               ...
# 19940                          111.9800                [ERKEK, AKTIFSPOR]
# 19941                          239.9900                       [AKTIFSPOR]
# 19942                          492.9600                       [AKTIFSPOR]
# 19943                          297.9800                [ERKEK, AKTIFSPOR]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
#        customer_value_total  order_num_total
# 0                  939.3700           5.0000
# 1                 2013.5500          21.0000
# 2                  585.3200           5.0000
# 3                  121.9700           2.0000
# 4                  209.9800           2.0000
# ...                     ...              ...
# 19940              401.9600           3.0000
# 19941              390.4700           2.0000
# 19942              632.9400           3.0000
# 19943             1009.7700           6.0000
# 19944              261.9700           2.0000
#
# [19945 rows x 14 columns]

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 4: Değişken tiplerini inceleyiniz. Tarih ifade eden değişkenlerin tipini date'e çeviriniz.
# #--------------------------------------------------------------------------------------------------------------------------#
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  object
#  4   last_order_date                    19945 non-null  object
#  5   last_order_date_online             19945 non-null  object
#  6   last_order_date_offline            19945 non-null  object
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  customer_value_total               19945 non-null  float64
#  13  order_num_total                    19945 non-null  float64
# dtypes: float64(6), object(8)
# memory usage: 2.1+ MB

# %%
df[["first_order_date","last_order_date","last_order_date_online","last_order_date_offline"]]=df[["first_order_date","last_order_date","last_order_date_online","last_order_date_offline"]].astype('datetime64[ns]')
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 3           2021-01-06      2021-01-17             2021-01-17
# 4           2019-08-03      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19940       2019-09-21      2020-07-05             2020-06-05
# 19941       2020-03-01      2020-12-22             2020-12-22
# 19942       2019-09-11      2021-05-24             2021-05-24
# 19943       2019-03-27      2021-02-13             2021-02-13
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 3                  2021-01-06                       1.0000
# 4                  2019-08-03                       1.0000
# ...                       ...                          ...
# 19940              2020-07-05                       1.0000
# 19941              2020-03-01                       1.0000
# 19942              2019-09-11                       2.0000
# 19943              2021-01-08                       1.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 3                            1.0000                            39.9900
# 4                            1.0000                            49.9900
# ...                             ...                                ...
# 19940                        2.0000                           289.9800
# 19941                        1.0000                           150.4800
# 19942                        1.0000                           139.9800
# 19943                        5.0000                           711.7900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12  \
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 3                               81.9800               [AKTIFCOCUK, COCUK]
# 4                              159.9900                       [AKTIFSPOR]
# ...                                 ...                               ...
# 19940                          111.9800                [ERKEK, AKTIFSPOR]
# 19941                          239.9900                       [AKTIFSPOR]
# 19942                          492.9600                       [AKTIFSPOR]
# 19943                          297.9800                [ERKEK, AKTIFSPOR]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
#        customer_value_total  order_num_total
# 0                  939.3700           5.0000
# 1                 2013.5500          21.0000
# 2                  585.3200           5.0000
# 3                  121.9700           2.0000
# 4                  209.9800           2.0000
# ...                     ...              ...
# 19940              401.9600           3.0000
# 19941              390.4700           2.0000
# 19942              632.9400           3.0000
# 19943             1009.7700           6.0000
# 19944              261.9700           2.0000
#
# [19945 rows x 14 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19945 entries, 0 to 19944
# Data columns (total 14 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   master_id                          19945 non-null  object
#  1   order_channel                      19945 non-null  object
#  2   last_order_channel                 19945 non-null  object
#  3   first_order_date                   19945 non-null  datetime64[ns]
#  4   last_order_date                    19945 non-null  datetime64[ns]
#  5   last_order_date_online             19945 non-null  datetime64[ns]
#  6   last_order_date_offline            19945 non-null  datetime64[ns]
#  7   order_num_total_ever_online        19945 non-null  float64
#  8   order_num_total_ever_offline       19945 non-null  float64
#  9   customer_value_total_ever_offline  19945 non-null  float64
#  10  customer_value_total_ever_online   19945 non-null  float64
#  11  interested_in_categories_12        19945 non-null  object
#  12  customer_value_total               19945 non-null  float64
#  13  order_num_total                    19945 non-null  float64
# dtypes: datetime64[ns](4), float64(6), object(4)
# memory usage: 2.1+ MB

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 5: Alışveriş kanallarındaki müşteri sayısının, toplam alınan ürün sayısının ve toplam harcamaların dağılımına bakınız.
# #--------------------------------------------------------------------------------------------------------------------------#
df["master_id"].value_counts().sum()
# Out:
# 19945

# %%
df["order_num_total"].value_counts().sum()
# Out:
# 19945

# %%
df["customer_value_total"].value_counts().sum()
# Out:
# 19945

# %%
df.groupby("interested_in_categories_12").agg({"customer_value_total":"sum"}).sort_values(
    by="customer_value_total",ascending=False).head(5)
# Out:
#                              customer_value_total
# interested_in_categories_12
# [AKTIFSPOR]                          2373965.8700
# [KADIN]                              1139066.0200
# []                                   1136553.5500
# [KADIN, AKTIFSPOR]                   1132049.5600
# [ERKEK]                              1106934.4400

# %%
df.groupby("interested_in_categories_12").agg({"order_num_total":"sum"}).sort_values(
    by="order_num_total",ascending=False).head(5)
# Out:
#                              order_num_total
# interested_in_categories_12
# [AKTIFSPOR]                       14000.0000
# [KADIN]                            9084.0000
# [ERKEK]                            8160.0000
# []                                 7710.0000
# [KADIN, AKTIFSPOR]                 6942.0000

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 6: En fazla kazancı getiren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
df.groupby("master_id").agg({"customer_value_total":"sum"}).sort_values(
    by="customer_value_total",ascending=False).head(10)
# Out:
#                                       customer_value_total
# master_id
# 5d1c466a-9cfd-11e9-9897-000d3a38a36f            45905.1000
# d5ef8058-a5c6-11e9-a2fc-000d3a38a36f            36818.2900
# 73fd19aa-9e37-11e9-9897-000d3a38a36f            33918.1000
# 7137a5c0-7aad-11ea-8f20-000d3a38a36f            31227.4100
# 47a642fe-975b-11eb-8c2a-000d3a38a36f            20706.3400
# a4d534a2-5b1b-11eb-8dbd-000d3a38a36f            18443.5700
# d696c654-2633-11ea-8e1c-000d3a38a36f            16918.5700
# fef57ffa-aae6-11e9-a2fc-000d3a38a36f            12726.1000
# cba59206-9dd1-11e9-9897-000d3a38a36f            12282.2400
# fc0ce7a4-9d87-11e9-9897-000d3a38a36f            12103.1500

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 7: En fazla siparişi veren ilk 10 müşteriyi sıralayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
df.groupby("master_id").agg({"order_num_total":"sum"}).sort_values(
    by="order_num_total",ascending=False).head(10)
# Out:
#                                       order_num_total
# master_id
# 5d1c466a-9cfd-11e9-9897-000d3a38a36f         202.0000
# cba59206-9dd1-11e9-9897-000d3a38a36f         131.0000
# a57f4302-b1a8-11e9-89fa-000d3a38a36f         111.0000
# fdbe8304-a7ab-11e9-a2fc-000d3a38a36f          88.0000
# 329968c6-a0e2-11e9-a2fc-000d3a38a36f          83.0000
# 73fd19aa-9e37-11e9-9897-000d3a38a36f          82.0000
# 44d032ee-a0d4-11e9-a2fc-000d3a38a36f          77.0000
# b27e241a-a901-11e9-a2fc-000d3a38a36f          75.0000
# d696c654-2633-11ea-8e1c-000d3a38a36f          70.0000
# a4d534a2-5b1b-11eb-8dbd-000d3a38a36f          70.0000

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 8: Veri ön hazırlık sürecini fonksiyonlaştırınız.
# #--------------------------------------------------------------------------------------------------------------------------#

def on_hazırlik(df):
    # #--------------------------------------------------------------------------------------------------------------------------#
    # Adım 3: Omnichannel müşterilerin hem online'dan hemde offline platformlardan alışveriş yaptığını ifade etmektedir. Her bir müşterinin toplam
    # alışveriş sayısı ve harcaması için yeni değişkenler oluşturunuz.
    # #--------------------------------------------------------------------------------------------------------------------------#
    df["customer_value_total"]=df["customer_value_total_ever_online"]+df["customer_value_total_ever_offline"]
    df["order_num_total"]=df["order_num_total_ever_online"]+df["order_num_total_ever_offline"]
    # #--------------------------------------------------------------------------------------------------------------------------#
    # Adım 4: Değişken tiplerini inceleyiniz. Tarih ifade eden değişkenlerin tipini date'e çeviriniz.
    # #--------------------------------------------------------------------------------------------------------------------------#
    df[["first_order_date","last_order_date","last_order_date_online","last_order_date_offline"]]=df[["first_order_date","last_order_date","last_order_date_online","last_order_date_offline"]].astype('datetime64[ns]')
    return df
df = df_.copy()
df=on_hazırlik(df)
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 3           2021-01-06      2021-01-17             2021-01-17
# 4           2019-08-03      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19940       2019-09-21      2020-07-05             2020-06-05
# 19941       2020-03-01      2020-12-22             2020-12-22
# 19942       2019-09-11      2021-05-24             2021-05-24
# 19943       2019-03-27      2021-02-13             2021-02-13
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 3                  2021-01-06                       1.0000
# 4                  2019-08-03                       1.0000
# ...                       ...                          ...
# 19940              2020-07-05                       1.0000
# 19941              2020-03-01                       1.0000
# 19942              2019-09-11                       2.0000
# 19943              2021-01-08                       1.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 3                            1.0000                            39.9900
# 4                            1.0000                            49.9900
# ...                             ...                                ...
# 19940                        2.0000                           289.9800
# 19941                        1.0000                           150.4800
# 19942                        1.0000                           139.9800
# 19943                        5.0000                           711.7900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12  \
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 3                               81.9800               [AKTIFCOCUK, COCUK]
# 4                              159.9900                       [AKTIFSPOR]
# ...                                 ...                               ...
# 19940                          111.9800                [ERKEK, AKTIFSPOR]
# 19941                          239.9900                       [AKTIFSPOR]
# 19942                          492.9600                       [AKTIFSPOR]
# 19943                          297.9800                [ERKEK, AKTIFSPOR]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
#        customer_value_total  order_num_total
# 0                  939.3700           5.0000
# 1                 2013.5500          21.0000
# 2                  585.3200           5.0000
# 3                  121.9700           2.0000
# 4                  209.9800           2.0000
# ...                     ...              ...
# 19940              401.9600           3.0000
# 19941              390.4700           2.0000
# 19942              632.9400           3.0000
# 19943             1009.7700           6.0000
# 19944              261.9700           2.0000
#
# [19945 rows x 14 columns]

# %% [markdown]
# # Görev 2: RFM Metriklerinin Hesaplanması

# %%
# #Görev 2: RFM Metriklerinin Hesaplanması

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: Recency, Frequency ve Monetary tanımlarını yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Müşteri özelinde Recency, Frequency ve Monetary metriklerini hesaplayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Hesapladığınız metrikleri rfm isimli bir değişkene atayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 4: Oluşturduğunuz metriklerin isimlerini recency, frequency ve monetary olarak değiştiriniz.
# recency değerini hesaplamak için analiz tarihini maksimum tarihten 2 gün sonrası seçebilirsiniz
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
df
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3      1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
# 4      d6ea1074-f1f5-11e9-9346-000d3a38a36f       Desktop            Desktop
# ...                                     ...           ...                ...
# 19940  727e2b6e-ddd4-11e9-a848-000d3a38a36f   Android App            Offline
# 19941  25cd53d4-61bf-11ea-8dd8-000d3a38a36f       Desktop            Desktop
# 19942  8aea4c2a-d6fc-11e9-93bc-000d3a38a36f       Ios App            Ios App
# 19943  e50bb46c-ff30-11e9-a5e8-000d3a38a36f   Android App        Android App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 3           2021-01-06      2021-01-17             2021-01-17
# 4           2019-08-03      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19940       2019-09-21      2020-07-05             2020-06-05
# 19941       2020-03-01      2020-12-22             2020-12-22
# 19942       2019-09-11      2021-05-24             2021-05-24
# 19943       2019-03-27      2021-02-13             2021-02-13
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 3                  2021-01-06                       1.0000
# 4                  2019-08-03                       1.0000
# ...                       ...                          ...
# 19940              2020-07-05                       1.0000
# 19941              2020-03-01                       1.0000
# 19942              2019-09-11                       2.0000
# 19943              2021-01-08                       1.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 3                            1.0000                            39.9900
# 4                            1.0000                            49.9900
# ...                             ...                                ...
# 19940                        2.0000                           289.9800
# 19941                        1.0000                           150.4800
# 19942                        1.0000                           139.9800
# 19943                        5.0000                           711.7900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12  \
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 3                               81.9800               [AKTIFCOCUK, COCUK]
# 4                              159.9900                       [AKTIFSPOR]
# ...                                 ...                               ...
# 19940                          111.9800                [ERKEK, AKTIFSPOR]
# 19941                          239.9900                       [AKTIFSPOR]
# 19942                          492.9600                       [AKTIFSPOR]
# 19943                          297.9800                [ERKEK, AKTIFSPOR]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
#        customer_value_total  order_num_total
# 0                  939.3700           5.0000
# 1                 2013.5500          21.0000
# 2                  585.3200           5.0000
# 3                  121.9700           2.0000
# 4                  209.9800           2.0000
# ...                     ...              ...
# 19940              401.9600           3.0000
# 19941              390.4700           2.0000
# 19942              632.9400           3.0000
# 19943             1009.7700           6.0000
# 19944              261.9700           2.0000
#
# [19945 rows x 14 columns]

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: Recency, Frequency ve Monetary tanımlarını yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#

# Cevap

# "last_order_date" değişkenindeki son işlem tarihini bulup bu tarihten 2 gün sonra bu modeli kurduğumuzu varsayıyoruz. 
# bu nedenle her müşteri için ayrı ayrı
# Recency :  last_order_date_plus_2  tarihi ile fark 
# Frequency : order_num_total
# Monetary : customer_value_total
#     değerlei bize istediğimiz değerleri verecektir

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Müşteri özelinde Recency, Frequency ve Monetary metriklerini hesaplayınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: Hesapladığınız metrikleri rfm isimli bir değişkene atayınız.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
df["last_order_date"].max()   # son gün
# Out:
# Timestamp('2021-05-30 00:00:00')

# %%
last_order_date_plus_2 = df["last_order_date"].max()+timedelta(days=2)
last_order_date_plus_2
# Out:
# Timestamp('2021-06-01 00:00:00')

# %%
df.master_id.nunique()
# Out:
# 19945

# %%
len(df)
# Out:
# 19945

# %%
# tüm id ler eşsiz

# %%
rfm = df.groupby('master_id').agg({'last_order_date': lambda last_order_date: (last_order_date_plus_2 - last_order_date),#.days, # recency
                                   'order_num_total': lambda order_num_total: order_num_total,#frequency
                                   'customer_value_total': lambda customer_value_total: customer_value_total}) # Monetary
rfm.last_order_date=[i.days for i in rfm.last_order_date]
rfm.head()
# Out:
#                                       last_order_date  order_num_total  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f               10           5.0000
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              298           3.0000
# 000be838-85df-11ea-a90b-000d3a38a36f              213           4.0000
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f               27           7.0000
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f               20           7.0000
#
#                                       customer_value_total
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              776.0700
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              269.4700
# 000be838-85df-11ea-a90b-000d3a38a36f              722.6900
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             1620.3300

# %%
# Adım 4: Oluşturduğunuz metriklerin isimlerini recency, frequency ve monetary olarak değiştiriniz.
# recency değerini hesaplamak için analiz tarihini maksimum tarihten 2 gün sonrası seçebilirsiniz
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
rfm.columns = ['recency', 'frequency', 'monetary']
rfm
# Out:
#                                       recency  frequency  monetary
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298     3.0000  269.4700
# 000be838-85df-11ea-a90b-000d3a38a36f      213     4.0000  722.6900
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# ...                                       ...        ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f      183     5.0000  796.8700
# fff4736a-60a4-11ea-8dd8-000d3a38a36f       67     2.0000  318.8700
# fffacd34-ae14-11e9-a2fc-000d3a38a36f      257     6.0000  983.9200
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
# fffe4b30-18e0-11ea-9213-000d3a38a36f      321     4.0000  524.6900
#
# [19945 rows x 3 columns]

# %% [markdown]
# # Görev 3: RF Skorunun Hesaplanması

# %%
# #Görev 3: RF Skorunun Hesaplanması

# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: Recency, Frequency ve Monetary metriklerini qcut yardımı ile 1-5 arasında skorlara çeviriniz. 
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Bu skorları recency_score, frequency_score ve monetary_score olarak kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: recency_score ve frequency_score’u tek bir değişken olarak ifade ediniz ve RF_SCORE olarak kaydediniz. 
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: Recency, Frequency ve Monetary metriklerini qcut yardımı ile 1-5 arasında skorlara çeviriniz. 
# #--------------------------------------------------------------------------------------------------------------------------#
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Bu skorları recency_score, frequency_score ve monetary_score olarak kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#



rfm["recency_score"] = pd.qcut(rfm['recency'], 5, labels=[5, 4, 3, 2, 1]) # ters sıralıyoruz--küçük olan değerlidir
# örneğin qcut-5 : 0-100 >>> 0-20, 20-40, 40-60, 60-80, 80-100
rfm["frequency_score"] = pd.qcut(rfm['frequency'].rank(method="first"), 5, labels=[1, 2, 3, 4, 5]) 
#method="first"  >>> aynı değeri ilk gruba koyar
rfm["monetary_score"] = pd.qcut(rfm['monetary'], 5, labels=[1, 2, 3, 4, 5])
rfm
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298     3.0000  269.4700
# 000be838-85df-11ea-a90b-000d3a38a36f      213     4.0000  722.6900
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# ...                                       ...        ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f      183     5.0000  796.8700
# fff4736a-60a4-11ea-8dd8-000d3a38a36f       67     2.0000  318.8700
# fffacd34-ae14-11e9-a2fc-000d3a38a36f      257     6.0000  983.9200
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
# fffe4b30-18e0-11ea-9213-000d3a38a36f      321     4.0000  524.6900
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# ...                                            ...             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f             2               4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f             4               2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f             1               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
# fffe4b30-18e0-11ea-9213-000d3a38a36f             1               4
#
#                                      monetary_score
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1
# 000be838-85df-11ea-a90b-000d3a38a36f              4
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5
# ...                                             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f              4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f              2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f              4
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5
# fffe4b30-18e0-11ea-9213-000d3a38a36f              3
#
# [19945 rows x 6 columns]

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 3: recency_score ve frequency_score’u tek bir değişken olarak ifade ediniz ve RF_SCORE olarak kaydediniz. 
# #--------------------------------------------------------------------------------------------------------------------------#
rfm["RFM_SCORE"] = (rfm['recency_score'].astype(str) +
                    rfm['frequency_score'].astype(str))
rfm
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298     3.0000  269.4700
# 000be838-85df-11ea-a90b-000d3a38a36f      213     4.0000  722.6900
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# ...                                       ...        ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f      183     5.0000  796.8700
# fff4736a-60a4-11ea-8dd8-000d3a38a36f       67     2.0000  318.8700
# fffacd34-ae14-11e9-a2fc-000d3a38a36f      257     6.0000  983.9200
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
# fffe4b30-18e0-11ea-9213-000d3a38a36f      321     4.0000  524.6900
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# ...                                            ...             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f             2               4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f             4               2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f             1               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
# fffe4b30-18e0-11ea-9213-000d3a38a36f             1               4
#
#                                      monetary_score RFM_SCORE
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4        54
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1        12
# 000be838-85df-11ea-a90b-000d3a38a36f              4        23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4        54
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5        54
# ...                                             ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f              4        24
# fff4736a-60a4-11ea-8dd8-000d3a38a36f              2        42
# fffacd34-ae14-11e9-a2fc-000d3a38a36f              4        14
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5        35
# fffe4b30-18e0-11ea-9213-000d3a38a36f              3        14
#
# [19945 rows x 7 columns]

# %% [markdown]
# # Görev 4: RF Skorunun Segment Olarak Tanımlanması

# %%
# #Görev 4: RF Skorunun Segment Olarak Tanımlanması
    
# #--------------------------------------------------------------------------------------------------------------------------#    
# Adım 1: Oluşturulan RF skorları için segment tanımlamaları yapınız.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: Aşağıdaki seg_map yardımı ile skorları segmentlere çeviriniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 1: Segmentlerin recency, frequnecy ve monetary ortalamalarını inceleyiniz.
# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: RFM analizi yardımıyla aşağıda verilen 2 case için ilgili profildeki müşterileri bulun ve müşteri id'lerini csv olarak kaydediniz.

#     a. FLO bünyesine yeni bir kadın ayakkabı markası dahil ediyor. Dahil ettiği markanın ürün fiyatları genel müşteri
# tercihlerinin üstünde. Bu nedenle markanın tanıtımı ve ürün satışları için ilgilenecek profildeki müşterilerle özel olarak
# iletişime geçmek isteniliyor. Sadık müşterilerinden(champions, loyal_customers) ve kadın kategorisinden alışveriş
# yapan kişiler özel olarak iletişim kurulacak müşteriler. Bu müşterilerin id numaralarını csv dosyasına kaydediniz.
#     b. Erkek ve Çocuk ürünlerinde %40'a yakın indirim planlanmaktadır. Bu indirimle ilgili kategorilerle ilgilenen geçmişte
# iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler, uykuda olanlar ve yeni
# gelen müşteriler özel olarak hedef alınmak isteniyor. Uygun profildeki müşterilerin id'lerini csv dosyasına kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
Image("segments.png")

# %%
# regex  >>  regular explaination

# RFM isimlendirmesi
seg_map = {
    r'[1-2][1-2]': 'hibernating',  # birinci elemanında 1 yada 2,ikinci elemanında 1 yada 2 görürsen onları hibernating yap
    r'[1-2][3-4]': 'at_Risk',
    r'[1-2]5': 'cant_loose',
    r'3[1-2]': 'about_to_sleep',
    r'33': 'need_attention',
    r'[3-4][4-5]': 'loyal_customers',
    r'41': 'promising',
    r'51': 'new_customers',
    r'[4-5][2-3]': 'potential_loyalists',
    r'5[4-5]': 'champions'
}

rfm['segment'] = rfm['RFM_SCORE'].replace(seg_map, regex=True)
rfm
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 00034aaa-a838-11e9-a2fc-000d3a38a36f      298     3.0000  269.4700
# 000be838-85df-11ea-a90b-000d3a38a36f      213     4.0000  722.6900
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# ...                                       ...        ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f      183     5.0000  796.8700
# fff4736a-60a4-11ea-8dd8-000d3a38a36f       67     2.0000  318.8700
# fffacd34-ae14-11e9-a2fc-000d3a38a36f      257     6.0000  983.9200
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
# fffe4b30-18e0-11ea-9213-000d3a38a36f      321     4.0000  524.6900
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 00034aaa-a838-11e9-a2fc-000d3a38a36f             1               2
# 000be838-85df-11ea-a90b-000d3a38a36f             2               3
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# ...                                            ...             ...
# fff1db94-afd9-11ea-b736-000d3a38a36f             2               4
# fff4736a-60a4-11ea-8dd8-000d3a38a36f             4               2
# fffacd34-ae14-11e9-a2fc-000d3a38a36f             1               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
# fffe4b30-18e0-11ea-9213-000d3a38a36f             1               4
#
#                                      monetary_score RFM_SCORE  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4        54
# 00034aaa-a838-11e9-a2fc-000d3a38a36f              1        12
# 000be838-85df-11ea-a90b-000d3a38a36f              4        23
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4        54
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5        54
# ...                                             ...       ...
# fff1db94-afd9-11ea-b736-000d3a38a36f              4        24
# fff4736a-60a4-11ea-8dd8-000d3a38a36f              2        42
# fffacd34-ae14-11e9-a2fc-000d3a38a36f              4        14
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5        35
# fffe4b30-18e0-11ea-9213-000d3a38a36f              3        14
#
#                                                   segment
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f            champions
# 00034aaa-a838-11e9-a2fc-000d3a38a36f          hibernating
# 000be838-85df-11ea-a90b-000d3a38a36f              at_Risk
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f            champions
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f            champions
# ...                                                   ...
# fff1db94-afd9-11ea-b736-000d3a38a36f              at_Risk
# fff4736a-60a4-11ea-8dd8-000d3a38a36f  potential_loyalists
# fffacd34-ae14-11e9-a2fc-000d3a38a36f              at_Risk
# fffacecc-ddc3-11e9-a848-000d3a38a36f      loyal_customers
# fffe4b30-18e0-11ea-9213-000d3a38a36f              at_Risk
#
# [19945 rows x 8 columns]

# %%
rfm[["segment", "recency", "frequency", "monetary"]].groupby("segment").agg(["mean", "count"]).sort_values(
    by=("recency","mean"))
# Out:
#                      recency       frequency        monetary
#                         mean count      mean count      mean count
# segment
# champions            17.1422  1920    8.9651  1920 1410.7089  1920
# new_customers        17.9762   673    2.0000   673  344.0495   673
# potential_loyalists  36.8697  2925    3.3108  2925  533.7413  2925
# promising            58.6946   668    2.0000   668  334.1533   668
# loyal_customers      82.5579  3375    8.3564  3375 1216.2572  3375
# need_attention      113.0372   806    3.7395   806  553.4366   806
# about_to_sleep      114.0316  1643    2.4066  1643  361.6494  1643
# cant_loose          235.1591  1194   10.7169  1194 1481.6524  1194
# at_Risk             242.3290  3152    4.4702  3152  648.3250  3152
# hibernating         247.4263  3589    2.3915  3589  362.5833  3589

# %% [markdown]
# # Görev 5: Aksiyon Zamanı

# %%
# #--------------------------------------------------------------------------------------------------------------------------#

# #Görev 5: Aksiyon Zamanı 

# #--------------------------------------------------------------------------------------------------------------------------#
# Adım 2: RFM analizi yardımıyla aşağıda verilen 2 case için ilgili profildeki müşterileri bulun ve müşteri id'lerini csv olarak kaydediniz.

#     a. FLO bünyesine yeni bir kadın ayakkabı markası dahil ediyor. Dahil ettiği markanın ürün fiyatları genel müşteri
# tercihlerinin üstünde. Bu nedenle markanın tanıtımı ve ürün satışları için ilgilenecek profildeki müşterilerle özel olarak
# iletişime geçmek isteniliyor. Sadık müşterilerinden(champions, loyal_customers) ve kadın kategorisinden alışveriş
# yapan kişiler özel olarak iletişim kurulacak müşteriler. Bu müşterilerin id numaralarını csv dosyasına kaydediniz.
#     b. Erkek ve Çocuk ürünlerinde %40'a yakın indirim planlanmaktadır. Bu indirimle ilgili kategorilerle ilgilenen geçmişte
# iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler, uykuda olanlar ve yeni
# gelen müşteriler özel olarak hedef alınmak isteniyor. Uygun profildeki müşterilerin id'lerini csv dosyasına kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
df[df["interested_in_categories_12"].astype(str).str.contains("KADIN", na=False)]
# Out:
#                                   master_id order_channel last_order_channel  \
# 0      cc294636-19f0-11eb-8d74-000d3a38a36f   Android App            Offline
# 1      f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2      69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 5      e585280e-aae1-11e9-a2fc-000d3a38a36f       Desktop            Offline
# 8      cfbda69e-5b4f-11ea-aca7-000d3a38a36f   Android App        Android App
# ...                                     ...           ...                ...
# 19926  7e1c15be-6298-11ea-9861-000d3a38a36f   Android App        Android App
# 19932  13a5e98c-a824-11e9-a2fc-000d3a38a36f   Android App            Offline
# 19934  9777eb76-bed4-11ea-958c-000d3a38a36f       Desktop            Offline
# 19937  515ca2d8-afdc-11e9-9757-000d3a38a36f       Ios App            Ios App
# 19944  740998d2-b1f7-11e9-89fa-000d3a38a36f   Android App        Android App
#
#       first_order_date last_order_date last_order_date_online  \
# 0           2020-10-30      2021-02-26             2021-02-21
# 1           2017-02-08      2021-02-16             2021-02-16
# 2           2019-11-27      2020-11-27             2020-11-27
# 5           2018-11-18      2021-03-13             2018-11-18
# 8           2020-01-23      2021-03-07             2021-03-07
# ...                ...             ...                    ...
# 19926       2019-02-16      2021-05-22             2021-05-22
# 19932       2015-03-23      2020-11-05             2020-06-28
# 19934       2020-07-05      2020-12-02             2020-11-28
# 19937       2019-03-10      2020-08-27             2020-08-27
# 19944       2019-09-03      2020-06-06             2020-06-06
#
#       last_order_date_offline  order_num_total_ever_online  \
# 0                  2021-02-26                       4.0000
# 1                  2020-01-10                      19.0000
# 2                  2019-12-01                       3.0000
# 5                  2021-03-13                       1.0000
# 8                  2020-01-25                       3.0000
# ...                       ...                          ...
# 19926              2020-03-06                       6.0000
# 19932              2020-11-05                       7.0000
# 19934              2020-12-02                       1.0000
# 19937              2019-09-04                       5.0000
# 19944              2019-09-03                       1.0000
#
#        order_num_total_ever_offline  customer_value_total_ever_offline  \
# 0                            1.0000                           139.9900
# 1                            2.0000                           159.9700
# 2                            2.0000                           189.9700
# 5                            2.0000                           150.8700
# 8                            2.0000                           120.4800
# ...                             ...                                ...
# 19926                        2.0000                           310.7000
# 19932                        2.0000                           210.7200
# 19934                        2.0000                           390.9600
# 19937                        1.0000                            39.9900
# 19944                        1.0000                            39.9900
#
#        customer_value_total_ever_online       interested_in_categories_12  \
# 0                              799.3800                           [KADIN]
# 1                             1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                              395.3500                    [ERKEK, KADIN]
# 5                               49.9900                           [KADIN]
# 8                              934.2100             [ERKEK, COCUK, KADIN]
# ...                                 ...                               ...
# 19926                         1062.3900                [KADIN, AKTIFSPOR]
# 19932                          963.2800         [ERKEK, KADIN, AKTIFSPOR]
# 19934                          143.9900                    [ERKEK, KADIN]
# 19937                          604.8800                    [COCUK, KADIN]
# 19944                          221.9800                [KADIN, AKTIFSPOR]
#
#        customer_value_total  order_num_total
# 0                  939.3700           5.0000
# 1                 2013.5500          21.0000
# 2                  585.3200           5.0000
# 5                  200.8600           3.0000
# 8                 1054.6900           5.0000
# ...                     ...              ...
# 19926             1373.0900           8.0000
# 19932             1174.0000           9.0000
# 19934              534.9500           3.0000
# 19937              644.8700           6.0000
# 19944              261.9700           2.0000
#
# [7603 rows x 14 columns]

# %%
rfm[(rfm["segment"]== "champions") | (rfm["segment"]== "loyal_customers") ]
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# 003903e0-abce-11e9-a2fc-000d3a38a36f       68     5.0000  577.4700
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f       99    12.0000  684.9100
# ...                                       ...        ...       ...
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f       15     7.0000 1423.3600
# ffe0ab60-6c79-11ea-9ddf-000d3a38a36f       93    11.0000 1441.9200
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f       75     4.0000  749.8400
# ffefdd18-77ca-11ea-9b70-000d3a38a36f       74     4.0000  208.4600
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# 003903e0-abce-11e9-a2fc-000d3a38a36f             4               4
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f             3               5
# ...                                            ...             ...
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f             5               5
# ffe0ab60-6c79-11ea-9ddf-000d3a38a36f             3               5
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f             4               4
# ffefdd18-77ca-11ea-9b70-000d3a38a36f             4               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
#
#                                      monetary_score RFM_SCORE          segment
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4        54        champions
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4        54        champions
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5        54        champions
# 003903e0-abce-11e9-a2fc-000d3a38a36f              3        44  loyal_customers
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f              4        35  loyal_customers
# ...                                             ...       ...              ...
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f              5        55        champions
# ffe0ab60-6c79-11ea-9ddf-000d3a38a36f              5        35  loyal_customers
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f              4        44  loyal_customers
# ffefdd18-77ca-11ea-9b70-000d3a38a36f              1        44  loyal_customers
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5        35  loyal_customers
#
# [5295 rows x 8 columns]

# %%
list_kadinlar=list(df[df["interested_in_categories_12"].astype(str).str.contains("KADIN", na=False)].master_id)
list_kadinlar[:2]
# Out:
# ['cc294636-19f0-11eb-8d74-000d3a38a36f',
#  'f431bd5a-ab7b-11e9-a2fc-000d3a38a36f']

# %%
rfm_women_champions_loyal_customers=rfm[(rfm["segment"]== "champions") | 
                                        (rfm["segment"]== "loyal_customers")  & 
                                        (rfm.index.isin(list_kadinlar))]
#rfm_women_champions_loyal_customers.to_csv("rfm_women_champions_loyal_customers")
rfm_women_champions_loyal_customers
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f       10     5.0000  776.0700
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f       27     7.0000  874.1600
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f       20     7.0000 1620.3300
# 003903e0-abce-11e9-a2fc-000d3a38a36f       68     5.0000  577.4700
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f       99    12.0000  684.9100
# ...                                       ...        ...       ...
# ffd73136-b098-11e9-9757-000d3a38a36f      100    16.0000 2511.4800
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f       15     7.0000 1423.3600
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f       75     4.0000  749.8400
# ffefdd18-77ca-11ea-9b70-000d3a38a36f       74     4.0000  208.4600
# fffacecc-ddc3-11e9-a848-000d3a38a36f      132     9.0000 1362.2000
#
#                                      recency_score frequency_score  \
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f             5               4
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f             5               4
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f             5               4
# 003903e0-abce-11e9-a2fc-000d3a38a36f             4               4
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f             3               5
# ...                                            ...             ...
# ffd73136-b098-11e9-9757-000d3a38a36f             3               5
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f             5               5
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f             4               4
# ffefdd18-77ca-11ea-9b70-000d3a38a36f             4               4
# fffacecc-ddc3-11e9-a848-000d3a38a36f             3               5
#
#                                      monetary_score RFM_SCORE          segment
# master_id
# 00016786-2f5a-11ea-bb80-000d3a38a36f              4        54        champions
# 000c1fe2-a8b7-11ea-8479-000d3a38a36f              4        54        champions
# 000f5e3e-9dde-11ea-80cd-000d3a38a36f              5        54        champions
# 003903e0-abce-11e9-a2fc-000d3a38a36f              3        44  loyal_customers
# 004bec18-9f7a-11e9-a2fc-000d3a38a36f              4        35  loyal_customers
# ...                                             ...       ...              ...
# ffd73136-b098-11e9-9757-000d3a38a36f              5        35  loyal_customers
# ffdd5eb8-aee9-11e9-a2fc-000d3a38a36f              5        55        champions
# ffe5c7e8-ee12-11e9-9346-000d3a38a36f              4        44  loyal_customers
# ffefdd18-77ca-11ea-9b70-000d3a38a36f              1        44  loyal_customers
# fffacecc-ddc3-11e9-a848-000d3a38a36f              5        35  loyal_customers
#
# [3511 rows x 8 columns]

# %%
# #--------------------------------------------------------------------------------------------------------------------------#
#     b. Erkek ve Çocuk ürünlerinde %40'a yakın indirim planlanmaktadır. Bu indirimle ilgili kategorilerle ilgilenen geçmişte
# iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler, uykuda olanlar ve yeni
# gelen müşteriler özel olarak hedef alınmak isteniyor. Uygun profildeki müşterilerin id'lerini csv dosyasına kaydediniz.
# #--------------------------------------------------------------------------------------------------------------------------#

# %%
df.interested_in_categories_12.unique()
# Out:
# array(['[KADIN]', '[ERKEK, COCUK, KADIN, AKTIFSPOR]', '[ERKEK, KADIN]',
#        '[AKTIFCOCUK, COCUK]', '[AKTIFSPOR]', '[COCUK]',
#        '[ERKEK, COCUK, KADIN]', '[KADIN, AKTIFSPOR]',
#        '[AKTIFCOCUK, COCUK, KADIN]', '[COCUK, KADIN, AKTIFSPOR]',
#        '[ERKEK, AKTIFSPOR]', '[AKTIFCOCUK, COCUK, AKTIFSPOR]', '[ERKEK]',
#        '[COCUK, KADIN]', '[ERKEK, KADIN, AKTIFSPOR]', '[AKTIFCOCUK]',
#        '[COCUK, AKTIFSPOR]', '[AKTIFCOCUK, ERKEK, KADIN, AKTIFSPOR]',
#        '[ERKEK, COCUK]', '[]', '[AKTIFCOCUK, COCUK, KADIN, AKTIFSPOR]',
#        '[AKTIFCOCUK, ERKEK, COCUK]', '[AKTIFCOCUK, ERKEK]',
#        '[AKTIFCOCUK, KADIN]',
#        '[AKTIFCOCUK, ERKEK, COCUK, KADIN, AKTIFSPOR]',
#        '[AKTIFCOCUK, ERKEK, COCUK, KADIN]', '[AKTIFCOCUK, AKTIFSPOR]',
#        '[AKTIFCOCUK, ERKEK, COCUK, AKTIFSPOR]',
#        '[AKTIFCOCUK, KADIN, AKTIFSPOR]', '[AKTIFCOCUK, ERKEK, AKTIFSPOR]',
#        '[ERKEK, COCUK, AKTIFSPOR]', '[AKTIFCOCUK, ERKEK, KADIN]'],
#       dtype=object)

# %%
df[(df["interested_in_categories_12"].astype(str).str.contains("ERKEK", na=False)) | 
   (df["interested_in_categories_12"].astype(str).str.contains("COCUK", na=False)) | 
   (df["interested_in_categories_12"].astype(str).str.contains("AKTIFCOCUK", na=False))].head(3)
# Out:
#                               master_id order_channel last_order_channel  \
# 1  f431bd5a-ab7b-11e9-a2fc-000d3a38a36f   Android App             Mobile
# 2  69b69676-1a40-11ea-941b-000d3a38a36f   Android App        Android App
# 3  1854e56c-491f-11eb-806e-000d3a38a36f   Android App        Android App
#
#   first_order_date last_order_date last_order_date_online  \
# 1       2017-02-08      2021-02-16             2021-02-16
# 2       2019-11-27      2020-11-27             2020-11-27
# 3       2021-01-06      2021-01-17             2021-01-17
#
#   last_order_date_offline  order_num_total_ever_online  \
# 1              2020-01-10                      19.0000
# 2              2019-12-01                       3.0000
# 3              2021-01-06                       1.0000
#
#    order_num_total_ever_offline  customer_value_total_ever_offline  \
# 1                        2.0000                           159.9700
# 2                        2.0000                           189.9700
# 3                        1.0000                            39.9900
#
#    customer_value_total_ever_online       interested_in_categories_12  \
# 1                         1853.5800  [ERKEK, COCUK, KADIN, AKTIFSPOR]
# 2                          395.3500                    [ERKEK, KADIN]
# 3                           81.9800               [AKTIFCOCUK, COCUK]
#
#    customer_value_total  order_num_total
# 1             2013.5500          21.0000
# 2              585.3200           5.0000
# 3              121.9700           2.0000

# %%
list_erkek_and_cocuk=list(df[(df["interested_in_categories_12"].astype(str).str.contains("ERKEK", na=False)) | 
   (df["interested_in_categories_12"].astype(str).str.contains("COCUK", na=False))| 
   (df["interested_in_categories_12"].astype(str).str.contains("AKTIFCOCUK", na=False))].master_id)
list_erkek_and_cocuk[:2]
# Out:
# ['f431bd5a-ab7b-11e9-a2fc-000d3a38a36f',
#  '69b69676-1a40-11ea-941b-000d3a38a36f']

# %%
# seg_map = {
#     r'[1-2][1-2]': 'hibernating',  # birinci elemanında 1 yada 2,ikinci elemanında 1 yada 2 görürsen onları hibernating yap
#     r'[1-2][3-4]': 'at_Risk',
#     r'[1-2]5': 'cant_loose',
#     r'3[1-2]': 'about_to_sleep',
#     r'33': 'need_attention',
#     r'[3-4][4-5]': 'loyal_customers',
#     r'41': 'promising',
#     r'51': 'new_customers',
#     r'[4-5][2-3]': 'potential_loyalists',
#     r'5[4-5]': 'champions'
# }

# %%
# geçmişte iyi müşteri olan ama uzun süredir alışveriş yapmayan kaybedilmemesi gereken müşteriler=='cant_loose'
# uykuda olanlar == 'about_to_sleep'
# yeni gelen müşteriler=="new_customers"

# %%
rfm_men_and_children_and_about_to_sleep_and_new_customers=rfm[(rfm["segment"]== "about_to_sleep") | 
                                        (rfm["segment"]== "cant_loose")| 
                                        (rfm["segment"]== "new_customers")  & 
                                        (rfm.index.isin(list_erkek_and_cocuk))]
#rfm_men_and_children_and_about_to_sleep_and_new_customers.to_csv("rfm_men_and_children_and_about_to_sleep_and_new_customers")
rfm_men_and_children_and_about_to_sleep_and_new_customers
# Out:
#                                       recency  frequency  monetary  \
# master_id
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f      126     2.0000  317.9100
# 00414e84-adc6-11e9-a2fc-000d3a38a36f      120     3.0000  303.4400
# 0053a6ea-ad0a-11e9-a2fc-000d3a38a36f      117     3.0000  394.4900
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f      355     8.0000  778.8800
# 00c2168c-a875-11e9-a2fc-000d3a38a36f      120     3.0000  381.9600
# ...                                       ...        ...       ...
# ff8cd532-544e-11ea-b1db-000d3a38a36f      105     2.0000  315.4100
# ffc01688-d643-11e9-93bc-000d3a38a36f      137     2.0000  225.9800
# ffc1b6b2-655a-11eb-add3-000d3a38a36f      119     2.0000  369.9700
# ffcd5ade-edfc-11e9-9346-000d3a38a36f       92     2.0000  210.9700
# ffce3990-26be-11ea-aaaa-000d3a38a36f      186     7.0000  680.4400
#
#                                      recency_score frequency_score  \
# master_id
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f             3               1
# 00414e84-adc6-11e9-a2fc-000d3a38a36f             3               2
# 0053a6ea-ad0a-11e9-a2fc-000d3a38a36f             3               2
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f             1               5
# 00c2168c-a875-11e9-a2fc-000d3a38a36f             3               2
# ...                                            ...             ...
# ff8cd532-544e-11ea-b1db-000d3a38a36f             3               2
# ffc01688-d643-11e9-93bc-000d3a38a36f             3               2
# ffc1b6b2-655a-11eb-add3-000d3a38a36f             3               2
# ffcd5ade-edfc-11e9-9346-000d3a38a36f             3               2
# ffce3990-26be-11ea-aaaa-000d3a38a36f             2               5
#
#                                      monetary_score RFM_SCORE         segment
# master_id
# 0018c6aa-ab6c-11e9-a2fc-000d3a38a36f              2        31  about_to_sleep
# 00414e84-adc6-11e9-a2fc-000d3a38a36f              2        32  about_to_sleep
# 0053a6ea-ad0a-11e9-a2fc-000d3a38a36f              2        32  about_to_sleep
# 007cdfe4-1f54-11ea-87bf-000d3a38a36f              4        15      cant_loose
# 00c2168c-a875-11e9-a2fc-000d3a38a36f              2        32  about_to_sleep
# ...                                             ...       ...             ...
# ff8cd532-544e-11ea-b1db-000d3a38a36f              2        32  about_to_sleep
# ffc01688-d643-11e9-93bc-000d3a38a36f              1        32  about_to_sleep
# ffc1b6b2-655a-11eb-add3-000d3a38a36f              2        32  about_to_sleep
# ffcd5ade-edfc-11e9-9346-000d3a38a36f              1        32  about_to_sleep
# ffce3990-26be-11ea-aaaa-000d3a38a36f              4        25      cant_loose
#
# [3008 rows x 8 columns]

# %%
#rfm_men_and_children_and_about_to_sleep_and_new_customers.to_csv("rfm_men_and_children_and_about_to_sleep_and_new_customers")
